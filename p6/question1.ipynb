# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\dushyant\\NLP\\hindi_reconstructed_sentences2.csv')

# %%
df.shape
# Out:
# (10000000, 1)

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.head()
# Out:
#                               reconstructed_sentence
# 0  उसे  तत्काल  ट्रेन  के  शौचालय  में  बंद  कर  ...
# 1  ऐसे  ही  एक  कार्यक्रम  का  एक  वीडियो  सोशल  ...
# 2  आरबीजीडी  की  टीम  ने  टास  जीत  कर  पहले  खेल...
# 3  इससे  आम  आदमी  की  गाढ़ी  कमाई  को  फर्जी  और ...
# 4  विधि  शिक्षा  एवं  विधि  सहायता  केन्द्र  सेंट...

# %%
df.shape
# Out:
# (10000000, 1)

# %%
df_val = df.iloc[:1000]
df_test= df.iloc[1000:2000]
df_train = df.iloc[2000:1000000]

# %%
df_test.shape, df_val.shape, df_train.shape
# Out:
# ((1000, 1), (1000, 1), (998000, 1))

# %%
import pickle
import random
import math
from collections import Counter, defaultdict
from typing import List, Dict, Tuple

# %%
counts ={}

for sen in df_train['reconstructed_sentence']:
    words = sen.split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1

# %%
U=len(counts)

# %%
counts_freq={}
for k,v in counts.items():
    counts_freq[v]=counts_freq.get(v,0)+1

# %%
len(counts_freq)
# Out:
# 2524

# %%
N = sum(counts.values())

# %%
print(N,U)
# Out:
# 18947241 324962

# %%
N1 = counts_freq.get(1, 0) 
print(N1)
# Out:
# 188797

# %%
mass_unseen = N1 / N

# %%
sorted_counts_freq = dict(sorted(counts_freq.items()))

# %%
max_c = max(sorted_counts_freq.keys())
print(max_c)
# Out:
# 780209

# %%
c_star_table={}
for c in range(1, max_c + 1):
    Nc = counts_freq.get(c, 0)
    Ncp1 = counts_freq.get(c + 1, 0)
    if Nc == 0:
        continue
    c_star = (c + 1) * (Ncp1 / Nc) if Ncp1 > 0 else float(c)
    c_star_table[c] = c_star

# %%
V_total = U + 100_000 
num_unseen = V_total - U

# %%
total_cstar = sum(c_star_table[counts[token]] for token in counts)
scale = 1 - mass_unseen
token_prob = {token: c_star_table[counts[token]] * scale / total_cstar for token in counts}

# %%
P_unseen_each = mass_unseen / num_unseen

# %%
for c in range(0,101):
    print(c,counts_freq.get(c,0),c_star_table.get(c,0))
# Out:
# 0 0 0
# 1 188797 0.42804705583245495
# 2 40407 1.3676590689731976
# 3 18421 2.3772867922479777
# 4 10948 3.459535988308367
# 5 7575 4.37940594059406
# 6 5529 5.352866702839573
# 7 4228 6.554399243140965
# 8 3464 7.2826212471131635
# 9 2803 8.544416696396718
# 10 2395 9.26847599164927
# 11 2018 10.495540138751238
# 12 1765 11.762606232294617
# 13 1597 12.325610519724483
# 14 1406 13.879800853485065
# 15 1301 13.823212913143736
# 16 1124 15.351423487544483
# 17 1015 16.68768472906404
# 18 941 17.970244420828905
# 19 890 18.674157303370787
# 20 831 17.613718411552348
# 21 697 20.35868005738881
# 22 645 22.85736434108527
# 23 641 22.27769110764431
# 24 595 23.991596638655462
# 25 571 25.453590192644484
# 26 559 24.923076923076923
# 27 516 25.77519379844961
# 28 475 28.08421052631579
# 29 460 30.58695652173913
# 30 469 27.100213219616208
# 31 410 28.01951219512195
# 32 359 34.654596100278546
# 33 377 32.19628647214854
# 34 357 32.450980392156865
# 35 331 37.1963746223565
# 36 342 33.97076023391813
# 37 314 40.05732484076434
# 38 331 31.22356495468278
# 39 265 46.94339622641509
# 40 311 35.9903536977492
# 41 273 43.53846153846154
# 42 283 39.20141342756184
# 43 258 38.542635658914726
# 44 226 48.18584070796461
# 45 242 45.239669421487605
# 46 238 42.85294117647059
# 47 217 44.0184331797235
# 48 199 48.26130653266332
# 49 196 50.76530612244898
# 50 199 54.58793969849247
# 51 213 46.629107981220656
# 52 191 43.84293193717277
# 53 158 61.17721518987342
# 54 179 48.24022346368715
# 55 157 63.847133757961785
# 56 179 57.0
# 57 179 52.815642458100555
# 58 163 53.20858895705521
# 59 147 64.08163265306123
# 60 157 53.61783439490446
# 61 138 65.14492753623189
# 62 145 60.827586206896555
# 63 140 66.28571428571429
# 64 145 57.827586206896555
# 65 129 59.860465116279066
# 66 117 68.71794871794872
# 67 120 73.66666666666666
# 68 130 56.261538461538464
# 69 106 72.64150943396227
# 70 110 69.06363636363636
# 71 107 67.28971962616822
# 72 100 77.38000000000001
# 73 106 83.07547169811322
# 74 119 71.84873949579833
# 75 114 66.66666666666666
# 76 100 77.0
# 77 100 80.34
# 78 103 79.0
# 79 103 80.7766990291262
# 80 104 73.21153846153847
# 81 94 89.85106382978724
# 82 103 90.25242718446601
# 83 112 48.75000000000001
# 84 65 104.61538461538463
# 85 80 81.7
# 86 76 108.75
# 87 95 69.47368421052632
# 88 75 97.30666666666666
# 89 82 103.17073170731706
# 90 94 54.212765957446805
# 91 56 115.0
# 92 70 96.9857142857143
# 93 73 104.3013698630137
# 94 81 87.96296296296296
# 95 75 90.88
# 96 71 86.07042253521126
# 97 63 93.33333333333333
# 98 60 128.70000000000002
# 99 78 69.23076923076923
# 100 54 130.92592592592592

# %%
epsilon = 1e-12
def sentence_logprob(df_subset):
    log_probs = []
    for sen in df_subset['reconstructed_sentence']:
        log_prob = 0.0
        for word in sen.split():
            p = token_prob.get(word, P_unseen_each)
            p = max(p, epsilon)
            log_prob += math.log(p)
        log_probs.append(log_prob)
    return log_probs

log_probs_test = sentence_logprob(df_test)
log_probs_val = sentence_logprob(df_val)

print(log_probs_test[:5])
print(log_probs_val[:5])
# Out:
# [-70.13599080682383, -117.81502305816342, -99.40931339232277, -104.62659912038113, -408.5971798670203]
# [-159.06877261042916, -84.91946583428575, -157.7340406531229, -140.56175642168213, -299.3386033725079]

# %%
def build_ngrams(sentences, n):
    ngram_counts = defaultdict(int)
    for sent in sentences:
        tokens = sent.split()
        tokens = ['<s>']*(n-1) + tokens + ['</s>']
        for i in range(len(tokens) - n + 1):
            ngram = tuple(tokens[i:i+n])
            ngram_counts[ngram] += 1
    return ngram_counts

# %%
bigrams = build_ngrams(df_train['reconstructed_sentence'], 2)

trigrams = build_ngrams(df_train['reconstructed_sentence'], 3)

quadrigrams = build_ngrams(df_train['reconstructed_sentence'], 4)

# %%
bigrams
# Out:
# defaultdict(int,
#             {('<s>', 'सुसाइड'): 26,
#              ('सुसाइड', 'करते'): 1,
#              ('करते', 'पुरूष'): 1,
#              ('पुरूष', ','): 11,
#              (',', 'हमरो'): 1,
#              ('हमरो', 'नहीं'): 1,
#              ('नहीं', 'यह'): 63,
#              ('यह', 'कार्य'): 124,
#              ('कार्य', '।'): 14,
#              ('।', '।'): 377,
#              ('।', '</s>'): 773477,
#              ('<s>', 'सवा'): 14,
#              ('सवा', 'मिनट'): 2,
#              ('मिनट', 'के'): 372,
#              ('के', 'इस'): 2957,
#              ('इस', 'वीडियो'): 753,
#              ('वीडियो', 'ने'): 28,
#              ('ने', 'पिछले'): 724,
#              ('पिछले', 'दिनों'): 816,
#              ('दिनों', 'सोशल'): 55,
#              ('सोशल', 'मीडिया'): 3851,
#              ('मीडिया', 'पर'): 2666,
#              ('पर', 'कई'): 680,
#              ('कई', 'लोगों'): 712,
#              ('लोगों', 'का'): 2397,
#              ('का', 'ध्यान'): 784,
#              ('ध्यान', 'अपनी'): 52,
#              ('अपनी', 'तरफ'): 119,
#              ('तरफ', 'खींचा'): 8,
#              ('खींचा', 'है'): 24,
#              ('है', '.'): 55674,
#              ('.', '</s>'): 195760,
#              ('<s>', 'राजद'): 121,
#              ('राजद', 'नेता'): 59,
#              ('नेता', 'के'): 246,
#              ('के', 'खिलाफ'): 10860,
#              ('खिलाफ', 'यह'): 32,
#              ('यह', 'बड़ी'): 41,
#              ('बड़ी', 'कार्रवाई'): 77,
#              ('कार्रवाई', 'उत्पाद'): 1,
#              ('उत्पाद', 'विभाग'): 34,
#              ('विभाग', 'की'): 1787,
#              ('की', 'टीम'): 3368,
#              ('टीम', 'ने'): 2782,
#              ('ने', 'की'): 747,
#              ('की', '।'): 11383,
#              ('<s>', 'इसका'): 2302,
#              ('इसका', 'भुगतान'): 11,
#              ('भुगतान', 'कर'): 117,
#              ('कर', 'दिया'): 15884,
#              ('दिया', 'गया'): 10298,
#              ('गया', '.'): 3313,
#              ('<s>', 'मुझे'): 1512,
#              ('मुझे', 'क्षमा'): 5,
#              ('क्षमा', 'करें'): 8,
#              ('करें', ','): 855,
#              (',', 'लेकिन'): 13704,
#              ('लेकिन', 'ईमानदार'): 1,
#              ('ईमानदार', 'लोगों'): 9,
#              ('लोगों', 'के'): 5550,
#              ('के', 'नरसंहार'): 9,
#              ('नरसंहार', 'में'): 11,
#              ('में', 'स्टालिन'): 6,
#              ('स्टालिन', 'की'): 7,
#              ('की', 'गैर'): 55,
#              ('गैर', '-'): 485,
#              ('-', 'भागीदारी'): 5,
#              ('भागीदारी', 'के'): 66,
#              ('के', 'बारे'): 7983,
#              ('बारे', 'में'): 10279,
#              ('में', 'आपके'): 209,
#              ('आपके', 'शब्द'): 4,
#              ('शब्द', 'आश्वस्त'): 1,
#              ('आश्वस्त', 'नहीं'): 16,
#              ('नहीं', 'हैं'): 2056,
#              ('हैं', '।'): 94196,
#              ('<s>', 'आग'): 384,
#              ('आग', 'लगने'): 432,
#              ('लगने', 'का'): 81,
#              ('का', 'कारण'): 873,
#              ('कारण', 'ठेला'): 1,
#              ('ठेला', 'पर'): 4,
#              ('पर', 'रखा'): 286,
#              ('रखा', 'एलपीजी'): 1,
#              ('एलपीजी', 'गैस'): 25,
#              ('गैस', 'सिलेंडर'): 160,
#              ('सिलेंडर', 'बताया'): 1,
#              ('बताया', 'जा'): 1560,
#              ('जा', 'रहा'): 13484,
#              ('रहा', 'है'): 31995,
#              ('है', '।'): 255596,
#              ('<s>', 'शनिवार'): 1266,
#              ('शनिवार', 'को'): 4016,
#              ('को', 'आप'): 219,
#              ('आप', 'सांसद'): 10,
#              ('सांसद', 'संजय'): 49,
#              ('संजय', 'सिंह'): 235,
#              ('सिंह', 'बीजेपी'): 3,
#              ('बीजेपी', 'पर'): 86,
#              ('पर', 'निशाना'): 618,
#              ('निशाना', 'साधते'): 262,
#              ('साधते', 'हुए'): 253,
#              ('हुए', 'ट्वीट'): 81,
#              ('ट्वीट', 'किया'): 872,
#              ('किया', 'कि'): 1979,
#              ('कि', ','): 1743,
#              (',', 'कई'): 350,
#              ('कई', 'पत्रकार'): 8,
#              ('पत्रकार', 'साथी'): 5,
#              ('साथी', 'पूछते'): 1,
#              ('पूछते', 'हैं'): 85,
#              ('हैं', ','): 19563,
#              (',', 'भाजपा'): 356,
#              ('भाजपा', 'दिल्ली'): 10,
#              ('दिल्ली', 'का'): 149,
#              ('का', 'चुनाव'): 564,
#              ('चुनाव', 'राष्ट्रवाद'): 1,
#              ('राष्ट्रवाद', 'पर'): 5,
#              ('पर', 'लड़ेगी'): 5,
#              ('लड़ेगी', 'आपका'): 1,
#              ('आपका', 'क्या'): 11,
#              ('क्या', 'कहना'): 38,
#              ('कहना', 'है'): 6405,
#              ('है', '?'): 2745,
#              ('?', '।'): 10,
#              ('<s>', 'बेगूसराय'): 67,
#              ('बेगूसराय', 'में'): 30,
#              ('में', 'भी'): 10497,
#              ('भी', 'स्कूलों'): 12,
#              ('स्कूलों', 'में'): 990,
#              ('में', 'एक'): 10875,
#              ('एक', 'बार'): 4066,
#              ('बार', 'फिर'): 2391,
#              ('फिर', 'से'): 3001,
#              ('से', 'रौनक'): 8,
#              ('रौनक', 'लौटी'): 2,
#              ('लौटी', 'है'): 15,
#              ('<s>', 'वैसे'): 1224,
#              ('वैसे', 'दक्षिण'): 2,
#              ('दक्षिण', 'भारत'): 158,
#              ('भारत', 'के'): 4227,
#              ('के', 'कई'): 2319,
#              ('कई', 'मंदिरों'): 20,
#              ('मंदिरों', 'में'): 385,
#              ('में', 'इस'): 3239,
#              ('इस', 'प्रकार'): 1032,
#              ('प्रकार', 'का'): 464,
#              ('का', 'अन्न'): 7,
#              ('अन्न', 'प्रसादम'): 1,
#              ('प्रसादम', 'वितरित'): 1,
#              ('वितरित', 'किया'): 121,
#              ('किया', 'जाता'): 3360,
#              ('जाता', 'है'): 15712,
#              ('<s>', 'लेकिन'): 10237,
#              ('लेकिन', 'पुलिस'): 250,
#              ('पुलिस', 'आरोपी'): 43,
#              ('आरोपी', 'के'): 357,
#              ('खिलाफ', 'कार्रवाई'): 488,
#              ('कार्रवाई', 'नहीं'): 499,
#              ('नहीं', 'कर'): 3096,
#              ('कर', 'रही'): 6001,
#              ('रही', 'है'): 23257,
#              ('<s>', 'पालक'): 29,
#              ('पालक', 'संपर्क'): 1,
#              ('संपर्क', 'के'): 31,
#              ('के', 'दौरान'): 13380,
#              ('दौरान', 'शिक्षा'): 12,
#              ('शिक्षा', 'गुणवत्ता'): 9,
#              ('गुणवत्ता', 'में'): 100,
#              ('में', 'सुधार'): 1065,
#              ('सुधार', 'के'): 237,
#              ('के', 'प्रयासों'): 254,
#              ('प्रयासों', 'को'): 84,
#              ('को', 'तेज'): 208,
#              ('तेज', 'करते'): 18,
#              ('करते', 'हुए'): 11711,
#              ('हुए', 'लर्निंग'): 1,
#              ('लर्निंग', 'को'): 5,
#              ('को', 'बढ़ावा'): 750,
#              ('बढ़ावा', 'देने'): 430,
#              ('देने', 'एवं'): 19,
#              ('एवं', 'बच्चों'): 22,
#              ('बच्चों', 'के'): 1706,
#              ('के', 'साथ'): 43280,
#              ('साथ', 'सकारात्मक'): 9,
#              ('सकारात्मक', 'भाषा'): 1,
#              ('भाषा', 'का'): 171,
#              ('का', 'प्रयोग'): 1152,
#              ('प्रयोग', 'करने'): 154,
#              ('करने', ','): 559,
#              (',', 'बच्चों'): 132,
#              ('के', 'गृह'): 182,
#              ('गृह', 'कार्य'): 6,
#              ('कार्य', 'एवं'): 28,
#              ('एवं', 'शैक्षिक'): 9,
#              ('शैक्षिक', 'कार्यों'): 8,
#              ('कार्यों', 'की'): 319,
#              ('की', 'चर्चा'): 449,
#              ('चर्चा', 'को'): 23,
#              ('को', 'तरजीह'): 45,
#              ('तरजीह', 'देने'): 11,
#              ('देने', 'के'): 3454,
#              ('साथ', 'घरों'): 14,
#              ('घरों', 'में'): 1152,
#              ('में', 'बच्चों'): 415,
#              ('बच्चों', 'को'): 2447,
#              ('को', 'पढ़ने'): 60,
#              ('पढ़ने', 'के'): 140,
#              ('के', 'लिए'): 99660,
#              ('लिए', 'अनुकूल'): 62,
#              ('अनुकूल', 'शैक्षिक'): 1,
#              ('शैक्षिक', 'वातावरण'): 3,
#              ('वातावरण', 'प्रदान'): 10,
#              ('प्रदान', 'करने'): 534,
#              ('करने', 'एवं'): 88,
#              ('एवं', 'बेहतर'): 7,
#              ('बेहतर', 'समय'): 12,
#              ('समय', 'प्रबंधन'): 12,
#              ('प्रबंधन', ','): 59,
#              (',', 'सुपोषण'): 1,
#              ('सुपोषण', 'के'): 3,
#              ('साथ', 'बच्चों'): 34,
#              ('को', 'लगातार'): 255,
#              ('लगातार', 'मोटिवेट'): 2,
#              ('मोटिवेट', 'करने'): 5,
#              ('करने', 'हेतु'): 167,
#              ('हेतु', 'पालकों'): 1,
#              ('पालकों', 'को'): 21,
#              ('को', 'जागरूक'): 375,
#              ('जागरूक', 'किया'): 256,
#              ('किया', 'गया'): 20335,
#              ('गया', '।'): 25394,
#              ('<s>', 'भारत'): 4391,
#              ('भारत', 'ने'): 1325,
#              ('ने', 'इससे'): 182,
#              ('इससे', 'पहले'): 3585,
#              ('पहले', 'टी'): 23,
#              ('टी', '-'): 767,
#              ('-', '20'): 1269,
#              ('20', 'अंतरराष्ट्रीय'): 27,
#              ('अंतरराष्ट्रीय', 'मैचों'): 23,
#              ('मैचों', 'की'): 503,
#              ('की', 'सीरीज'): 239,
#              ('सीरीज', '2'): 52,
#              ('2', '-'): 681,
#              ('-', '1'): 1066,
#              ('1', 'से'): 407,
#              ('से', 'अपने'): 1275,
#              ('अपने', 'नाम'): 586,
#              ('नाम', 'की'): 739,
#              ('की', 'थी'): 5465,
#              ('थी', '।'): 23215,
#              ('<s>', 'वहीं'): 11580,
#              ('वहीं', ','): 2850,
#              (',', 'अर्जेंटीना'): 19,
#              ('अर्जेंटीना', 'के'): 44,
#              ('के', '11'): 233,
#              ('11', 'मैचों'): 15,
#              ('मैचों', 'में'): 723,
#              ('में', '25'): 370,
#              ('25', 'अंक'): 8,
#              ('अंक', 'हैं'): 50,
#              ('<s>', 'इनमें'): 2582,
#              ('इनमें', 'शुरुआती'): 2,
#              ('शुरुआती', 'इम्यून'): 1,
#              ('इम्यून', 'रिस्पॉन्स'): 2,
#              ('रिस्पॉन्स', 'की'): 3,
#              ('की', 'क्षमता'): 725,
#              ('क्षमता', ','): 38,
#              (',', 'एंटीबॉडी'): 2,
#              ('एंटीबॉडी', 'में'): 5,
#              ('में', 'कमी'): 774,
#              ('कमी', 'आने'): 63,
#              ('आने', 'की'): 800,
#              ('की', 'दर'): 589,
#              ('दर', ','): 14,
#              (',', 'म्यूटेट'): 1,
#              ('म्यूटेट', 'होने'): 3,
#              ('होने', 'की'): 4535,
#              ('की', 'पैथोजेन'): 1,
#              ('पैथोजेन', 'की'): 1,
#              ('की', 'टेंडेंसी'): 2,
#              ('टेंडेंसी', 'के'): 1,
#              ('साथ', '-'): 2147,
#              ('-', 'साथ'): 2128,
#              ('साथ', 'शरीर'): 20,
#              ('शरीर', 'का'): 176,
#              ('का', 'कौन'): 20,
#              ('कौन', 'हिस्सा'): 1,
#              ('हिस्सा', 'संक्रमित'): 2,
#              ('संक्रमित', 'होता'): 8,
#              ('होता', 'है'): 11103,
#              ('है', ','): 39245,
#              (',', 'ये'): 892,
#              ('ये', 'तमाम'): 15,
#              ('तमाम', 'फैक्टर'): 1,
#              ('फैक्टर', 'अहम'): 1,
#              ('अहम', 'हैं'): 32,
#              ('<s>', 'इस'): 39232,
#              ('इस', 'मौके'): 1488,
#              ('मौके', 'पर'): 6589,
#              ('पर', 'उत्तराखंड'): 26,
#              ('उत्तराखंड', 'बाल'): 3,
#              ('बाल', 'संरक्षण'): 60,
#              ('संरक्षण', 'अधिकार'): 3,
#              ('अधिकार', 'आयोग'): 18,
#              ('आयोग', 'की'): 545,
#              ('की', 'अध्यक्ष'): 244,
#              ('अध्यक्ष', 'ऊषा'): 3,
#              ('ऊषा', 'नेगी'): 3,
#              ('नेगी', 'ने'): 126,
#              ('ने', 'बताया'): 17392,
#              ('बताया', 'कि'): 22316,
#              ('कि', 'राज्य'): 768,
#              ('राज्य', 'के'): 1952,
#              ('के', 'सभी'): 2615,
#              ('सभी', '13'): 14,
#              ('13', 'जिलों'): 16,
#              ('जिलों', 'में'): 1250,
#              ('में', 'पुलिस'): 1895,
#              ('पुलिस', 'की'): 2035,
#              ('की', 'मदद'): 2430,
#              ('मदद', 'से'): 1555,
#              ('से', 'इस'): 1628,
#              ('इस', 'तरह'): 3659,
#              ('तरह', 'के'): 2466,
#              ('के', 'बाल'): 91,
#              ('बाल', 'मित्र'): 7,
#              ('मित्र', 'पुलिस'): 4,
#              ('पुलिस', 'थानों'): 38,
#              ('थानों', 'की'): 82,
#              ('की', 'शुरुआत'): 2775,
#              ('शुरुआत', 'की'): 688,
#              ('की', 'जाएगी'): 2518,
#              ('जाएगी', '।'): 5178,
#              ('<s>', 'नई'): 6518,
#              ('नई', 'दिल्ली'): 5522,
#              ('दिल्ली', 'भारतीय'): 29,
#              ('भारतीय', 'जनता'): 1215,
#              ('जनता', 'पार्टी'): 1231,
#              ('पार्टी', 'BJP'): 34,
#              ('BJP', 'की'): 12,
#              ('की', 'राज्यसभा'): 11,
#              ('राज्यसभा', 'सांसद'): 192,
#              ('सांसद', 'रूपा'): 2,
#              ('रूपा', 'गांगुली'): 6,
#              ('गांगुली', 'गुरुवार'): 2,
#              ('गुरुवार', 'को'): 3346,
#              ('को', 'सदन'): 69,
#              ('सदन', 'में'): 497,
#              ('में', 'विपक्ष'): 157,
#              ('विपक्ष', 'पर'): 55,
#              ('पर', 'भड़क'): 16,
#              ('भड़क', 'गई'): 30,
#              ('गई', '.'): 1867,
#              ('<s>', 'मां'): 435,
#              ('मां', 'नर्मदा'): 36,
#              ('नर्मदा', 'के'): 48,
#              ('के', 'जल'): 97,
#              ('जल', 'की'): 74,
#              ('की', 'अगवानी'): 24,
#              ('अगवानी', 'ग्रामीणों'): 1,
#              ('ग्रामीणों', 'ने'): 1211,
#              ('ने', 'ढोल'): 8,
#              ('ढोल', '-'): 32,
#              ('-', 'ताशे'): 1,
#              ('ताशे', 'पर'): 1,
#              ('पर', 'नाचकर'): 1,
#              ('नाचकर', 'की'): 1,
#              ('<s>', '्रुणाल'): 1,
#              ('्रुणाल', 'पंड्या'): 1,
#              ('पंड्या', 'ने'): 39,
#              ('ने', 'बल्ले'): 13,
#              ('बल्ले', 'और'): 16,
#              ('और', 'गेंद'): 36,
#              ('गेंद', 'से'): 75,
#              ('से', 'बिखेरी'): 1,
#              ('बिखेरी', 'चमक'): 1,
#              ('चमक', '।'): 2,
#              ('<s>', 'उन्होंने'): 23269,
#              ('उन्होंने', 'अपने'): 845,
#              ('अपने', 'बेटे'): 326,
#              ('बेटे', 'के'): 271,
#              ('के', 'दिल'): 183,
#              ('दिल', ','): 15,
#              (',', 'दोनों'): 376,
#              ('दोनों', 'किडनियां'): 3,
#              ('किडनियां', 'और'): 2,
#              ('और', 'लिवर'): 12,
#              ('लिवर', 'दान'): 2,
#              ('दान', 'कर'): 48,
#              ('कर', 'दीं'): 58,
#              ('दीं', '।'): 188,
#              ('<s>', 'इसके'): 22423,
#              ('इसके', 'साथ'): 2833,
#              ('साथ', 'ही'): 11496,
#              ('ही', 'अन्य'): 135,
#              ('अन्य', 'दोनों'): 9,
#              ('दोनों', 'कर्मचारियों'): 14,
#              ('कर्मचारियों', 'ने'): 516,
#              ('ने', 'वहां'): 174,
#              ('वहां', 'से'): 1208,
#              ('से', 'भागकर'): 32,
#              ('भागकर', 'अपनी'): 10,
#              ('अपनी', 'जान'): 425,
#              ('जान', 'बचाई'): 91,
#              ('बचाई', '।'): 58,
#              ('<s>', 'इसी'): 6106,
#              ('इसी', 'नाज़ी'): 1,
#              ('नाज़ी', 'फिज़िशियन'): 1,
#              ('फिज़िशियन', 'बैंड्ट'): 1,
#              ('बैंड्ट', 'को'): 1,
#              ('को', 'योजना'): 55,
#              ('योजना', 'बनने'): 1,
#              ('बनने', 'के'): 832,
#              ('के', 'बाद'): 36117,
#              ('बाद', 'यूथेनेशिया'): 1,
#              ('यूथेनेशिया', 'प्रोग्राम'): 1,
#              ('प्रोग्राम', 'का'): 34,
#              ('का', 'डायरेक्टर'): 5,
#              ('डायरेक्टर', 'बनाया'): 5,
#              ('बनाया', 'गया'): 1644,
#              ('गया', 'था'): 11222,
#              ('था', '.'): 8192,
#              ('<s>', 'Samsung'): 56,
#              ('Samsung', 'Galaxy'): 76,
#              ('Galaxy', 'Z'): 3,
#              ('Z', 'Fold'): 3,
#              ('Fold', '2'): 1,
#              ('2', 'के'): 234,
#              ('में', 'आपने'): 93,
#              ('आपने', 'सुना'): 27,
#              ('सुना', 'ही'): 16,
#              ('ही', 'होगा'): 311,
#              ('होगा', '।'): 9587,
#              ('<s>', 'वे'): 3075,
#              ('वे', 'एक'): 281,
#              ('एक', 'संत'): 23,
#              ('संत', 'की'): 14,
#              ('की', 'तरह'): 3726,
#              ('तरह', 'संगठन'): 1,
#              ('संगठन', 'का'): 102,
#              ('का', 'काम'): 3441,
#              ('काम', 'करते'): 857,
#              ('करते', 'रहे'): 543,
#              ('रहे', '।'): 4233,
#              ('<s>', 'इसे'): 2221,
#              ('इसे', "'"): 49,
#              ("'", 'हरित'): 1,
#              ('हरित', 'नगर'): 1,
#              ('नगर', "'"): 1,
#              ("'", 'ग्रीन'): 5,
#              ('ग्रीन', 'सीटी)'): 1,
#              ('सीटी)', 'कहा'): 1,
#              ('कहा', 'जाता'): 1578,
#              ('<s>', 'सुबह'): 1141,
#              ('सुबह', 'देर'): 11,
#              ('देर', 'तक'): 438,
#              ('तक', 'दरवाजा'): 4,
#              ('दरवाजा', 'नहीं'): 33,
#              ('नहीं', 'खुलने'): 21,
#              ('खुलने', 'से'): 88,
#              ('से', 'घर'): 559,
#              ('घर', 'के'): 1800,
#              ('के', 'अन्य'): 931,
#              ('अन्य', 'सदस्य'): 70,
#              ('सदस्य', 'जब'): 5,
#              ('जब', 'दरवाजा'): 10,
#              ('दरवाजा', 'खोल'): 13,
#              ('खोल', 'कर'): 64,
#              ('कर', 'देखें'): 11,
#              ('देखें', ','): 66,
#              (',', 'तो'): 6855,
#              ('तो', 'सभी'): 209,
#              ('सभी', 'बेसुध'): 1,
#              ('बेसुध', 'पाये'): 1,
#              ('पाये', 'गये'): 88,
#              ('गये', '.'): 265,
#              ('<s>', 'पुलिस'): 8023,
#              ('पुलिस', 'ने'): 10863,
#              ('ने', 'मौके'): 401,
#              ('पर', 'पहुंचकर'): 381,
#              ('पहुंचकर', 'चोरी'): 4,
#              ('चोरी', 'का'): 192,
#              ('का', 'जायजा'): 502,
#              ('जायजा', 'लिया'): 336,
#              ('लिया', '।'): 5479,
#              ('<s>', 'हां'): 301,
#              ('हां', 'हमने'): 4,
#              ('हमने', 'उन्हें'): 52,
#              ('उन्हें', 'डंडा'): 1,
#              ('डंडा', 'लाने'): 1,
#              ('लाने', 'के'): 662,
#              ('लिए', 'कहा'): 975,
#              ('कहा', 'था'): 3154,
#              ('था', '।'): 36738,
#              ('<s>', 'पिथौरागढ़'): 42,
#              ('पिथौरागढ़', 'जिले'): 13,
#              ('जिले', 'के'): 4403,
#              ('के', 'मंदिरों'): 51,
#              ('में', 'नवरात्र'): 22,
#              ('नवरात्र', 'पर'): 21,
#              ('पर', 'मंदिरों'): 12,
#              ('में', 'आदि'): 7,
#              ('आदि', 'शक्ति'): 15,
#              ('शक्ति', 'दुर्गा'): 1,
#              ('दुर्गा', 'के'): 49,
#              ('के', 'सातवें'): 57,
#              ('सातवें', 'रूप'): 1,
#              ('रूप', 'मां'): 3,
#              ('मां', 'कालरात्रि'): 12,
#              ('कालरात्रि', 'की'): 12,
#              ('की', 'पूजा'): 876,
#              ('पूजा', 'की'): 321,
#              ('की', 'गई'): 11028,
#              ('गई', '।'): 15741,
#              ('<s>', 'अगर'): 4430,
#              ('अगर', 'आप'): 1811,
#              ('आप', 'इन'): 99,
#              ('इन', 'चंद'): 2,
#              ('चंद', 'फूड्स'): 1,
#              ('फूड्स', 'को'): 8,
#              ('को', 'उचित'): 107,
#              ('उचित', 'तरीके'): 10,
#              ('तरीके', 'से'): 2349,
#              ('अपने', 'किचन'): 9,
#              ('किचन', 'में'): 75,
#              ('में', 'रखते'): 584,
#              ('रखते', 'हैं'): 689,
#              ('तो', 'ये'): 505,
#              ('ये', 'हमेशा'): 10,
#              ('हमेशा', 'के'): 160,
#              ('लिए', 'रह'): 7,
#              ('रह', 'सकते'): 160,
#              ('सकते', 'हैं'): 12152,
#              ('हैं', '!'): 256,
#              ('!', '</s>'): 4224,
#              ('<s>', 'भूखे'): 6,
#              ('भूखे', 'श्रमिक'): 1,
#              ('श्रमिक', 'को'): 16,
#              ('को', 'भोजन'): 155,
#              ('भोजन', 'मिलने'): 5,
#              ('मिलने', 'के'): 1450,
#              ('बाद', 'सुकून'): 1,
#              ('सुकून', 'मिला'): 7,
#              ('मिला', '।'): 1797,
#              ('<s>', 'पदोन्नति'): 19,
#              ('पदोन्नति', 'के'): 29,
#              ('के', 'योग'): 230,
#              ('योग', 'बनेंगे'): 11,
#              ('बनेंगे', '.'): 36,
#              ('<s>', 'कार्य'): 104,
#              ('कार्य', 'मन'): 3,
#              ('मन', 'मुताबिक'): 6,
#              ('मुताबिक', 'न'): 3,
#              ('न', 'होने'): 1169,
#              ('होने', 'पर'): 3099,
#              ('पर', 'निराश'): 7,
#              ('निराश', 'न'): 10,
#              ('न', 'हो'): 1173,
#              ('हो', '.'): 736,
#              ('<s>', 'Hero'): 3,
#              ('Hero', 'Motors'): 2,
#              ('Motors', 'Group'): 1,
#              ('Group', 'के'): 3,
#              ('के', 'उपकरण'): 64,
#              ('उपकरण', 'निर्माता'): 4,
#              ('निर्माता', 'हिस्सा'): 1,
#              ('हिस्सा', 'Hero'): 1,
#              ('Motors', 'ने'): 5,
#              ('ने', 'जापान'): 28,
#              ('जापान', 'की'): 91,
#              ('की', 'Yamaha'): 1,
#              ('Yamaha', 'कंपनी'): 1,
#              ('कंपनी', 'से'): 181,
#              ('से', 'साझेदारी'): 4,
#              ('साझेदारी', 'की'): 150,
#              ('की', 'है'): 10520,
#              ('<s>', 'SportsNews'): 1,
#              ('SportsNews', 'AsiaCup'): 1,
#              ('AsiaCup', 'TeamIndia'): 1,
#              ('TeamIndia', 'Captain'): 1,
#              ('Captain', 'ViratKohli'): 1,
#              ('ViratKohli', 'UAE'): 1,
#              ('UAE', 'BCCI'): 1,
#              ('BCCI', 'RohitSharma'): 1,
#              ('RohitSharma', 'वनडे'): 1,
#              ('वनडे', 'टूर्नामेंट'): 4,
#              ('टूर्नामेंट', '15'): 3,
#              ('15', 'सितंबर'): 77,
#              ('सितंबर', 'से'): 257,
#              ('से', 'खेला'): 40,
#              ('खेला', 'जाने'): 18,
#              ('जाने', 'एशिया'): 1,
#              ('एशिया', 'कप'): 95,
#              ('कप', 'क्रिकेट'): 15,
#              ('क्रिकेट', 'के'): 365,
#              ('लिए', 'भारतीय'): 183,
#              ('भारतीय', 'टीम'): 1052,
#              ('टीम', 'की'): 750,
#              ('की', 'घोषणा'): 2305,
#              ('घोषणा', 'हो'): 49,
#              ('हो', 'गई'): 11348,
#              ('गई', 'है'): 14733,
#              ('<s>', 'सभी'): 2207,
#              ('सभी', 'की'): 297,
#              ('की', 'जांच'): 4183,
#              ('जांच', 'चल'): 94,
#              ('चल', 'रही'): 2426,
#              ('<s>', 'अब'): 7227,
#              ('अब', 'सवाल'): 88,
#              ('सवाल', 'यह'): 192,
#              ('यह', 'उठता'): 42,
#              ('उठता', 'है'): 218,
#              (',', 'कि'): 476,
#              ('कि', 'आखिरकार'): 23,
#              ('आखिरकार', 'इन'): 2,
#              ('इन', 'दो'): 148,
#              ('दो', 'कम्पनियों'): 1,
#              ('कम्पनियों', 'के'): 23,
#              ('के', 'पास'): 9495,
#              ('पास', 'ऐसी'): 25,
#              ('ऐसी', 'क्या'): 18,
#              ('क्या', 'जड़ी'): 1,
#              ('जड़ी', 'बूटी'): 5,
#              ('बूटी', 'है'): 8,
#              ('कि', 'जिसे'): 21,
#              ('जिसे', 'सूंघकर'): 1,
#              ('सूंघकर', 'शासन'): 1,
#              ('शासन', 'के'): 423,
#              ('के', 'उड्डयन'): 5,
#              ('उड्डयन', 'विभाग'): 4,
#              ('विभाग', 'में'): 801,
#              ('में', 'चिपके'): 1,
#              ('चिपके', 'सम्बन्धित'): 1,
#              ('सम्बन्धित', 'अधिकारियों'): 12,
#              ('अधिकारियों', 'ने'): 1591,
#              ('ने', 'किराया'): 8,
#              ('किराया', 'घटाने'): 1,
#              ('घटाने', 'के'): 75,
#              ('के', 'बजाय'): 727,
#              ('बजाय', 'उसे'): 5,
#              ('उसे', 'बढ़ाना'): 1,
#              ('बढ़ाना', 'हितकर'): 1,
#              ('हितकर', 'समझा'): 1,
#              ('समझा', ','): 16,
#              (',', 'जबकि'): 3251,
#              ('जबकि', 'कई'): 80,
#              ('कई', 'वर्षों'): 193,
#              ('वर्षों', 'से'): 674,
#              ('से', 'हेली'): 1,
#              ('हेली', 'कम्पनियों'): 1,
#              ('के', 'मनमाने'): 5,
#              ('मनमाने', 'किराये'): 2,
#              ('किराये', 'के'): 61,
#              ('के', 'विरोध'): 1109,
#              ('विरोध', 'में'): 978,
#              ('में', 'स्वर'): 4,
#              ('स्वर', 'मुखर'): 4,
#              ('मुखर', 'होते'): 3,
#              ('होते', 'रहे'): 78,
#              ('रहे', 'हैं'): 25542,
#              ('<s>', 'नईदुनिया'): 587,
#              ('नईदुनिया', 'प्रतिनि;'): 34,
#              ('प्रतिनि;', 'घिळर्'): 36,
#              ('घिळर्', '-'): 46,
#              ('-', 'ऊि्\u200c'): 93,
#              ('ऊि्\u200c', '।'): 91,
#              ('<s>', 'अपनी'): 942,
#              ('अपनी', 'राय'): 142,
#              ('राय', 'mydw'): 1,
#              ('mydw', 'dw'): 1,
#              ('dw', '.'): 1,
#              ('.', 'd'): 20,
#              ('d', '</s>'): 20,
#              ('<s>', 'हाल'): 1562,
#              ('हाल', 'ही'): 3181,
#              ('ही', 'में'): 3107,
#              ('में', 'सिडनी'): 9,
#              ('सिडनी', 'के'): 15,
#              ('के', 'अस्पताल'): 182,
#              ('अस्पताल', 'में'): 3926,
#              ('में', 'हुए'): 1336,
#              ('हुए', 'दिल'): 2,
#              ('दिल', 'के'): 146,
#              ('के', 'ऑपरेशन'): 58,
#              ('ऑपरेशन', 'के'): 140,
#              ('बाद', 'केयर्न्स'): 1,
#              ('केयर्न्स', 'अब'): 1,
#              ('अब', 'पैरालिसिस'): 1,
#              ('पैरालिसिस', 'के'): 2,
#              ('के', 'शिकार'): 259,
#              ('शिकार', 'हो'): 319,
#              ('हो', 'गए'): 6165,
#              ('गए', 'हैं'): 7717,
#              ('हैं', '.'): 22771,
#              ('<s>', 'यह'): 16068,
#              ('यह', 'फिल्म'): 446,
#              ('फिल्म', 'उत्तर'): 2,
#              ('उत्तर', 'प्रदेश'): 4332,
#              ('प्रदेश', 'पुलिस'): 106,
#              ('की', 'छवि'): 222,
#              ('छवि', 'पर'): 17,
#              ('पर', 'प्रतिकूल'): 48,
#              ('प्रतिकूल', 'प्रभाव'): 51,
#              ('प्रभाव', 'डालती'): 12,
#              ('डालती', 'है'): 31,
#              ('<s>', 'एक'): 8119,
#              ('एक', 'आदमी'): 111,
#              ('आदमी', 'को'): 172,
#              ('को', 'अमृतफल'): 1,
#              ('अमृतफल', 'की'): 1,
#              ('की', 'जानकारी'): 3779,
#              ('जानकारी', 'मिली'): 424,
#              ('मिली', '।'): 1344,
#              ('<s>', 'बिना'): 338,
#              ('बिना', 'मास्क'): 173,
#              ('मास्क', 'मंदिर'): 1,
#              ('मंदिर', 'में'): 1394,
#              ('में', 'प्रवेश'): 1354,
#              ('प्रवेश', 'वर्जित'): 17,
#              ('वर्जित', 'रहेगा'): 8,
#              ('रहेगा', '।'): 2294,
#              ('यह', 'इंजन'): 39,
#              ('इंजन', '8'): 3,
#              ('8', 'hp'): 1,
#              ('hp', 'का'): 5,
#              ('का', 'पावर'): 29,
#              ('पावर', 'और'): 121,
#              ('और', '9.7'): 1,
#              ('9.7', 'Nm'): 1,
#              ('Nm', 'पीक'): 4,
#              ('पीक', 'टॉर्क'): 29,
#              ('टॉर्क', 'जेनरेट'): 48,
#              ('जेनरेट', 'करता'): 40,
#              ('करता', 'है'): 6533,
#              ('<s>', 'आप'): 2732,
#              ('आप', 'ऐसा'): 48,
#              ('ऐसा', 'जरूर'): 5,
#              ('जरूर', 'कर'): 34,
#              ('कर', 'सकते'): 5664,
#              ('<s>', 'जिसमें'): 2233,
#              ('जिसमें', 'उन्होंने'): 286,
#              ('उन्होंने', 'नगर'): 33,
#              ('नगर', 'पालिका'): 688,
#              ('पालिका', 'के'): 119,
#              ('के', 'ईओ'): 21,
#              ('ईओ', 'से'): 4,
#              ('से', 'कहा'): 2093,
#              ('कहा', 'कि'): 38101,
#              ('कि', 'सड़क'): 50,
#              ('सड़क', 'का'): 108,
#              ('का', 'जल्द'): 58,
#              ('जल्द', 'गुणवत्तापूर्ण'): 1,
#              ('गुणवत्तापूर्ण', 'तरीके'): 2,
#              ('से', 'निर्माण'): 56,
#              ('निर्माण', 'कराया'): 166,
#              ('कराया', 'जाए'): 162,
#              ('जाए', '।'): 3391,
#              ('<s>', 'माइक्रो'): 19,
#              ('माइक्रो', 'संगणक'): 1,
#              ('संगणक', 'पर्सनल'): 1,
#              ('पर्सनल', 'संगणक)'): 1,
#              ('संगणक)', 'सबसे'): 1,
#              ('सबसे', 'छोटे'): 54,
#              ('छोटे', 'होते'): 17,
#              ('होते', 'हैं'): 4029,
#              ('हैं', 'तथा'): 290,
#              ('तथा', 'इन्हीं'): 2,
#              ('इन्हीं', 'को'): 1,
#              ('को', 'वैयक्तिक'): 1,
#              ('वैयक्तिक', 'संगणक'): 1,
#              ('संगणक', 'या'): 1,
#              ('या', 'पर्सनल'): 1,
#              ('पर्सनल', 'संगणक'): 1,
#              ('संगणक', 'भी'): 1,
#              ('भी', 'कहा'): 1565,
#              ('<s>', 'ध्यप्रदेश'): 4,
#              ('ध्यप्रदेश', 'madhya'): 1,
#              ('madhya', 'pradesh'): 3,
#              ('pradesh', 'में'): 1,
#              ('में', 'ठगों'): 1,
#              ('ठगों', 'thug'): 1,
#              ('thug', 'का'): 1,
#              ('का', 'एक'): 4172,
#              ('एक', 'ऐसा'): 716,
#              ('ऐसा', 'गैंग'): 1,
#              ('गैंग', 'पकड़ा'): 2,
#              ('पकड़ा', 'गया'): 195,
#              ('गया', 'है'): 30531,
#              ('है', 'जो'): 4478,
#              ('जो', 'प्रधानमंत्री'): 10,
#              ('प्रधानमंत्री', 'और'): 92,
#              ('और', 'कोविड'): 84,
#              ('कोविड', '-'): 2379,
#              ('-', '19'): 3210,
#              ('19', 'के'): 937,
#              ('के', 'इलाज'): 445,
#              ('इलाज', 'के'): 1408,
#              ('के', 'नाम'): 5035,
#              ('नाम', 'पर'): 2123,
#              ('पर', 'लोगों'): 554,
#              ('लोगों', 'को'): 11362,
#              ('को', 'ठग'): 12,
#              ('ठग', 'रहा'): 1,
#              ('रहा', 'था'): 5883,
#              ('<s>', 'तभी'): 809,
#              ('तभी', 'से'): 180,
#              ('से', 'यह'): 1480,
#              ('यह', 'लगातार'): 60,
#              ('लगातार', 'जारी'): 180,
#              ('जारी', 'है'): 1785,
#              ('<s>', 'ंस्थापक'): 1,
#              ('ंस्थापक', 'संजय'): 1,
#              ('संजय', 'बांगड़'): 1,
#              ('बांगड़', 'ने'): 2,
#              ('ने', 'कहा'): 28779,
#              ('कहा', ','): 12138,
#              (',', "'"): 4850,
#              ("'", "'"): 1575,
#              ("'", 'क्रिकुरु'): 1,
#              ('क्रिकुरु', 'शुरू'): 1,
#              ('शुरू', 'करने'): 1010,
#              ('करने', 'का'): 7747,
#              ('का', 'मकसद'): 162,
#              ('मकसद', 'देश'): 10,
#              ('देश', 'भर'): 681,
#              ('भर', 'में'): 1441,
#              ('में', 'कहीं'): 328,
#              ('कहीं', 'भी'): 425,
#              ('भी', 'रहने'): 12,
#              ('रहने', 'वाले'): 2192,
#              ('वाले', 'यहां'): 4,
#              ('यहां', 'तक'): 958,
#              ('तक', 'कि'): 857,
#              ('कि', 'टियर'): 3,
#              ('टियर', '2'): 9,
#              ('2', 'और'): 101,
#              ('और', '3'): 181,
#              ('3', 'शहरों'): 5,
#              ('शहरों', 'में'): 758,
#              ('भी', 'लोगों'): 361,
#              ('लिए', 'क्रिकेट'): 20,
#              ('क्रिकेट', 'कोचिंग'): 2,
#              ('कोचिंग', 'तक'): 1,
#              ('तक', 'पहुंच'): 924,
#              ('पहुंच', 'प्रदान'): 15,
#              ('प्रदान', 'करना'): 109,
#              ('करना', 'है'): 1600,
#              ('है', 'जिसमें'): 1152,
#              ('जिसमें', 'आप'): 47,
#              ('आप', 'अपनी'): 411,
#              ('अपनी', 'सुविधा'): 30,
#              ('सुविधा', 'के'): 348,
#              ('के', 'अनुसार'): 10314,
#              ('अनुसार', 'घर'): 14,
#              ('घर', 'बैठे'): 210,
#              ('बैठे', 'शामिल'): 1,
#              ('शामिल', 'हो'): 650,
#              ('हो', 'सके'): 728,
#              ('सके', '।'): 2483,
#              ('<s>', 'बर्तनों'): 3,
#              ('बर्तनों', ','): 3,
#              (',', 'स्क्रैप'): 1,
#              ('स्क्रैप', 'और'): 2,
#              ('और', 'लोहे'): 15,
#              ('लोहे', 'पर'): 4,
#              ('पर', '18'): 55,
#              ('18', 'फीसद'): 5,
#              ('फीसद', 'जीएसटी'): 3,
#              ('जीएसटी', 'है'): 1,
#              ('है', 'जोकि'): 72,
#              ('जोकि', 'अन्य'): 2,
#              ('अन्य', 'वस्तुओं'): 14,
#              ('वस्तुओं', 'की'): 148,
#              ('की', 'तुलना'): 1451,
#              ('तुलना', 'में'): 1235,
#              ('में', 'अधिक'): 546,
#              ('अधिक', 'मानी'): 2,
#              ('मानी', 'जाती'): 188,
#              ('जाती', 'है'): 5809,
#              ('<s>', 'तहसील'): 109,
#              ('तहसील', 'के'): 288,
#              ('के', 'गांव'): 994,
#              ('गांव', 'कालुआना'): 1,
#              ('कालुआना', 'में'): 1,
#              ('में', 'जंडवाला'): 2,
#              ('जंडवाला', 'बिश्नोई'): 1,
#              ('बिश्नोई', 'रोड'): 1,
#              ('रोड', 'पर'): 1018,
#              ('पर', 'स्थित'): 629,
#              ('स्थित', 'गोशाला'): 6,
#              ('गोशाला', 'में'): 68,
#              ('में', 'बुधवार'): 737,
#              ('बुधवार', 'रात'): 203,
#              ('रात', 'अज्ञात'): 21,
#              ('अज्ञात', 'व्यक्ति'): 80,
#              ('व्यक्ति', 'ने'): 389,
#              ('ने', '65'): 17,
#              ('65', 'वर्षीय'): 50,
#              ('वर्षीय', 'चौकीदार'): 1,
#              ('चौकीदार', 'ओमप्रकाश'): 1,
#              ('ओमप्रकाश', 'का'): 5,
#              ('का', 'बेरहमी'): 5,
#              ('बेरहमी', 'से'): 143,
#              ('से', 'हत्या'): 96,
#              ('हत्या', 'कर'): 1259,
#              ('कर', 'दी'): 6698,
#              ('दी', '।'): 8152,
#              ('<s>', 'याचिका'): 211,
#              ('याचिका', 'में'): 360,
#              ('में', 'कहा'): 4232,
#              ('कहा', 'गया'): 3246,
#              ('है', 'कि'): 51090,
#              ('कि', 'मायावती'): 33,
#              ('मायावती', 'धर्म'): 1,
#              ('धर्म', ','): 121,
#              (',', 'जाति'): 77,
#              ('जाति', 'के'): 306,
#              ('पर', 'वोट'): 84,
#              ('वोट', 'मांग'): 22,
#              ('मांग', 'रही'): 45,
#              ('<s>', 'बाकी'): 314,
#              ('बाकी', 'पैसा'): 3,
#              ('पैसा', 'कहा'): 1,
#              ('कहा', 'जा'): 839,
#              ('<s>', 'वर्मा'): 48,
#              ('वर्मा', 'जी'): 6,
#              ('जी', 'के'): 734,
#              ('के', 'चिन्तन'): 2,
#              ('चिन्तन', 'में'): 1,
#              ('में', 'समग्रता'): 1,
#              ('समग्रता', 'थी'): 1,
#              ('इसके', 'बाद'): 8668,
#              ('बाद', 'आर्मी'): 8,
#              ('आर्मी', 'द्वारा'): 4,
#              ('द्वारा', 'रास्ते'): 1,
#              ('रास्ते', 'को'): 57,
#              ('को', 'पूरी'): 634,
#              ('पूरी', 'तरह'): 3664,
#              ('तरह', 'ब्लॉक'): 4,
#              ('ब्लॉक', 'किए'): 2,
#              ('किए', 'जाने'): 2015,
#              ('जाने', 'के'): 4088,
#              ('के', 'आसार'): 270,
#              ('आसार', 'बन'): 14,
#              ('बन', 'गए'): 602,
#              ('<s>', 'बीते'): 911,
#              ('बीते', '14'): 15,
#              ('14', 'अगस्त'): 88,
#              ('अगस्त', 'को'): 1075,
#              ('को', 'महज'): 65,
#              ('महज', 'छह'): 16,
#              ('छह', 'जिलों'): 22,
#              ('में', 'बनाए'): 184,
#              ('बनाए', 'गए'): 930,
#              ('गए', 'केंद्रों'): 2,
#              ('केंद्रों', 'पर'): 573,
#              ('पर', 'ऑफलाइन'): 6,
#              ('ऑफलाइन', 'परीक्षा'): 12,
#              ('परीक्षा', 'कराई'): 31,
#              ('कराई', 'गई'): 613,
#              ('<s>', 'वह'): 5578,
#              ('वह', 'बहुत'): 173,
#              ('बहुत', 'ही'): 1691,
#              ('ही', 'चुनौतीपूर्ण'): 5,
#              ('चुनौतीपूर्ण', 'भूमिकाएं'): 1,
#              ('भूमिकाएं', 'करते'): 1,
#              ('करते', 'हैं'): 8555,
#              ('हैं', 'और'): 9184,
#              ('और', 'अपनी'): 598,
#              ('अपनी', 'फिल्मों'): 60,
#              ('फिल्मों', 'को'): 135,
#              ('को', 'समाज'): 90,
#              ('समाज', 'व'): 40,
#              ('व', 'सामाजिक'): 42,
#              ('सामाजिक', 'मुद्दों'): 17,
#              ('मुद्दों', 'से'): 46,
#              ('से', 'जोड़ते'): 14,
#              ('जोड़ते', 'हैं'): 4,
#              ('अपनी', 'मातृ'): 3,
#              ('मातृ', 'भाषा'): 10,
#              ('भाषा', 'को'): 144,
#              ('को', 'जानना'): 56,
#              ('जानना', ','): 3,
#              (',', 'समझना'): 6,
#              ('समझना', 'और'): 14,
#              ('और', 'उसका'): 420,
#              ('उसका', 'सम्मान'): 15,
#              ('सम्मान', 'करना'): 74,
#              ('करना', 'सबके'): 4,
#              ('सबके', 'लिए'): 90,
#              ('लिए', 'परम'): 3,
#              ('परम', 'आवश्यक'): 4,
#              ('आवश्यक', 'है'): 592,
#              ('है', '!'): 629,
#              ('<s>', 'उद्घाटन'): 64,
#              ('उद्घाटन', 'समारोह'): 67,
#              ('समारोह', 'में'): 1115,
#              ('में', 'ध्वजवाहक'): 3,
#              ...})

# %%
def good_turing_probs(ngram_counts, V, n, V_extra=100_000):
    counts_freq = defaultdict(int)
    for c in ngram_counts.values():
        counts_freq[c] += 1
    
    N = sum(ngram_counts.values())     
    N1 = counts_freq.get(1, 0)         
    mass_unseen = N1 / N               
  
    max_c = max(counts_freq.keys())
    c_star_table = {}
    for c in range(1, max_c + 1):
        Nc = counts_freq.get(c, 0)
        Ncp1 = counts_freq.get(c+1, 0)
        if Nc == 0:
            continue
        c_star = (c+1)*(Ncp1/Nc) if Ncp1>0 else float(c)
        c_star_table[c] = c_star
    

    total_cstar = sum(c_star_table.get(count, count) for count in ngram_counts.values())
    scale = 1 - mass_unseen
    token_prob = {ng: c_star_table.get(count, count) * scale / total_cstar
                  for ng, count in ngram_counts.items()}
    
    
    U = len(ngram_counts)  
    V_total = V + V_extra
    num_unseen = (V_total ** n) - U
    P_unseen_each = mass_unseen / num_unseen
    
    return token_prob, P_unseen_each

# %%
def sentence_logprob(sentences, n, token_prob, P_unseen_each, epsilon=1e-12):
    log_probs = []
    for sen in sentences:
        tokens = sen.split()
        log_prob = 0.0
        for i in range(len(tokens)-n+1):
            ngram = tuple(tokens[i:i+n])
            p = token_prob.get(ngram, P_unseen_each)
            log_prob += math.log(max(p, epsilon))
        log_probs.append(log_prob)
    return log_probs

# %%
train_vocab = set(word for sen in df_train['reconstructed_sentence'] for word in sen.split())
V = len(train_vocab)

# %%
bi_prob, bi_unseen = good_turing_probs(bigrams, V, 2)
tri_prob, tri_unseen = good_turing_probs(trigrams, V, 3)
quad_prob, quad_unseen = good_turing_probs(quadrigrams, V, 4)

# %%
log_probs_bigrams  = sentence_logprob(df_test['reconstructed_sentence'], 2, bi_prob, bi_unseen)
log_probs_trigrams = sentence_logprob(df_test['reconstructed_sentence'], 3, tri_prob, tri_unseen)
log_probs_quadrigrams = sentence_logprob(df_test['reconstructed_sentence'], 4, quad_prob, quad_unseen)
print(log_probs_quadrigrams[:5])
print(log_probs_trigrams[:5])
print(log_probs_bigrams[:5])
# Out:
# [-153.9087859967321, -303.941232275214, -293.21054775763486, -266.0713098665141, -1268.5421622559568]
# [-148.75652670091927, -309.0680785014838, -231.66573186003606, -233.41787028082024, -1009.4093737709453]
# [-132.04303060246627, -228.41266154465856, -159.16290119693576, -171.02332976559572, -696.9609308607262]

# %%
unigram =build_ngrams(df_train['reconstructed_sentence'], 1)

# %%
uni_prob,uni_unseen=good_turing_probs(unigram,V,1)

# %%
log_probs_unigram=sentence_logprob(df_test['reconstructed_sentence'],1,uni_prob,uni_unseen)

# %%
df_test["Prob_unigram"]=log_probs_unigram
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3187987856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["Prob_unigram"]=log_probs_unigram

# %%
df_test["Prob_bigram"] = log_probs_bigrams
df_test["Prob_trigram"] = log_probs_trigrams
df_test["Prob_quadrigram"] = log_probs_quadrigrams
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3942807670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["Prob_bigram"] = log_probs_bigrams
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3942807670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["Prob_trigram"] = log_probs_trigrams
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3942807670.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["Prob_quadrigram"] = log_probs_quadrigrams

# %%
df_test.to_csv("test_with_probs.csv", index=False)

# %%
log_probs_bigrams  = sentence_logprob(df_val['reconstructed_sentence'], 2, bi_prob, bi_unseen)
log_probs_trigrams = sentence_logprob(df_val['reconstructed_sentence'], 3, tri_prob, tri_unseen)
log_probs_quadrigrams = sentence_logprob(df_val['reconstructed_sentence'], 4, quad_prob, quad_unseen)
print(log_probs_quadrigrams[:5])
print(log_probs_trigrams[:5])
print(log_probs_bigrams[:5])
# Out:
# [-490.7296943335773, -189.14388594514193, -379.7719009996225, -403.0879968730264, -772.168817821761]
# [-421.6821193366938, -151.53353073685884, -332.75966343743175, -358.0166068969892, -719.6531961018237]
# [-298.4892828687863, -126.127735474958, -252.1466599594539, -240.66308581555438, -557.4934188440463]

# %%
log_probs_unigram=sentence_logprob(df_val['reconstructed_sentence'], 1, uni_prob, uni_unseen)

# %%
df_val["Prob_uni"]=log_probs_unigram
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3389947198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Prob_uni"]=log_probs_unigram

# %%
df_val["Prob_bigram"] = log_probs_bigrams
df_val["Prob_trigram"] = log_probs_trigrams
df_val["Prob_quadrigram"] = log_probs_quadrigrams

df_val.to_csv("val_with_probs.csv", index=False)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3125594052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Prob_bigram"] = log_probs_bigrams
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3125594052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Prob_trigram"] = log_probs_trigrams
# C:\Users\sahil\AppData\Local\Temp\ipykernel_21708\3125594052.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Prob_quadrigram"] = log_probs_quadrigrams

# %%
df_val.to_csv("val_with_probs.csv", index=False)

# %%
df_val.head()
# Out:
#                               reconstructed_sentence  Prob_bigram  \
# 0  उसे  तत्काल  ट्रेन  के  शौचालय  में  बंद  कर  ...  -298.489283
# 1  ऐसे  ही  एक  कार्यक्रम  का  एक  वीडियो  सोशल  ...  -126.127735
# 2  आरबीजीडी  की  टीम  ने  टास  जीत  कर  पहले  खेल...  -252.146660
# 3  इससे  आम  आदमी  की  गाढ़ी  कमाई  को  फर्जी  और ...  -240.663086
# 4  विधि  शिक्षा  एवं  विधि  सहायता  केन्द्र  सेंट...  -557.493419
#
#    Prob_trigram  Prob_quadrigram    Prob_uni
# 0   -421.682119      -490.729694 -160.248090
# 1   -151.533531      -189.143886  -85.637311
# 2   -332.759663      -379.771901 -158.759582
# 3   -358.016607      -403.087997 -141.535975
# 4   -719.653196      -772.168818 -301.235767

# %%
df_test_prob=pd.read_csv('test_with_probs.csv')

# %%
df_test_prob.head()
# Out:
#                               reconstructed_sentence  Prob_bigram  \
# 0    करीब  दो  माह  पूर्व  विक्की  राजगढ़  आया  था ।  -132.043031
# 1  आपको  सही  जवाब  का  ऑप्शन  टाइप  कर  ये  एसएम...  -228.412662
# 2  वहीं  रात  में  ही  मुठभेड़  के  दौरान  उसका  ...  -159.162901
# 3  येलो  टी  बनाने  के  लिए , आपको  थोड़ा  पानी  ...  -171.023330
# 4  सुबह  10 बजे  से  11 बजे  तक  नामाकंन , 11 बजे...  -696.960931
#
#    Prob_trigram  Prob_quadrigram  Prob_unigram
# 0   -148.756527      -153.908786    -70.597463
# 1   -309.068079      -303.941232   -118.532916
# 2   -231.665732      -293.210548   -100.127159
# 3   -233.417870      -266.071310   -105.395719
# 4  -1009.409374     -1268.542162   -411.468562

# %%
df_val_prob=pd.read_csv('val_with_probs.csv')

# %%
df_val_prob.head()
# Out:
#                               reconstructed_sentence  Prob_bigram  \
# 0  उसे  तत्काल  ट्रेन  के  शौचालय  में  बंद  कर  ...  -298.489283
# 1  ऐसे  ही  एक  कार्यक्रम  का  एक  वीडियो  सोशल  ...  -126.127735
# 2  आरबीजीडी  की  टीम  ने  टास  जीत  कर  पहले  खेल...  -252.146660
# 3  इससे  आम  आदमी  की  गाढ़ी  कमाई  को  फर्जी  और ...  -240.663086
# 4  विधि  शिक्षा  एवं  विधि  सहायता  केन्द्र  सेंट...  -557.493419
#
#    Prob_trigram  Prob_quadrigram
# 0   -421.682119      -490.729694
# 1   -151.533531      -189.143886
# 2   -332.759663      -379.771901
# 3   -358.016607      -403.087997
# 4   -719.653196      -772.168818
